# %%
# input packages
import json
import pandas as pd

# %%
#input data

recipe_ar = pd.read_json('/Users/gunnuparinandi/Downloads/recipes_raw/recipes_raw_nosource_ar.json')
recipe_epi = pd.read_json('/Users/gunnuparinandi/Downloads/recipes_raw/recipes_raw_nosource_epi.json')
recipe_fn = pd.read_json('/Users/gunnuparinandi/Downloads/recipes_raw/recipes_raw_nosource_fn.json')

# %%
# get title of recipes.
recipe_ar.loc[['title']].values
# Out:
# array([['Slow Cooker Chicken and Dumplings',
#         'Awesome Slow Cooker Pot Roast', 'Brown Sugar Meatloaf', ...,
#         'Cooked Cold Salad', 'Easy Eggnog Creme Brulee',
#         'Super Power Stovetop Granola']], dtype=object)

# %%
recipe_ar.head()
# Out:
#                                 rmK12Uau.ntP510KeImX506H6Mr6jTu  \
# title                         Slow Cooker Chicken and Dumplings
# ingredients   [4 skinless, boneless chicken breast halves AD...
# instructions  Place the chicken, butter, soup, and onion in ...
# picture_link                    55lznCYBbs2mT8BTx6BTkLhynGHzM.S
#
#                                 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm  \
# title                             Awesome Slow Cooker Pot Roast
# ingredients   [2 (10.75 ounce) cans condensed cream of mushr...
# instructions  In a slow cooker, mix cream of mushroom soup, ...
# picture_link                    QyrvGdGNMBA2lDdciY0FjKu.77MM0Oe
#
#                                 clyYQv.CplpwJtjNaFGhx0VilNYqRxu  \
# title                                      Brown Sugar Meatloaf
# ingredients   [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# instructions  Preheat oven to 350 degrees F (175 degrees C)....
# ...

# %%
# create recipes columns from recipe_ar dataframe. includes titles and ingredients.
recipe_ar_title = pd.DataFrame(data = recipe_ar.loc[['title','ingredients']].values).transpose()
recipe_ar_title.columns=['recipe_title','ingredients']

# %%
recipe_ar_title.head()
# Out:
#                         recipe_title  \
# 0  Slow Cooker Chicken and Dumplings
# 1      Awesome Slow Cooker Pot Roast
# 2               Brown Sugar Meatloaf
# 3        Best Chocolate Chip Cookies
# 4  Homemade Mac and Cheese Casserole
#
#                                          ingredients
# 0  [4 skinless, boneless chicken breast halves AD...
# 1  [2 (10.75 ounce) cans condensed cream of mushr...
# 2  [1/2 cup packed brown sugar ADVERTISEMENT, 1/2...
# 3  [1 cup butter, softened ADVERTISEMENT, 1 cup w...
# 4  [8 ounces whole wheat rotini pasta ADVERTISEME...

# %%
#check null values
total_nulls=recipe_ar_title.isnull().sum().sort_values(ascending=False)
print("Total number of nulls for each feature:")
print(total_nulls)
# Out:
# Total number of nulls for each feature:
# ingredients     280
# recipe_title    280
# dtype: int64

# %%
# remove null values from dataset
recipe_ar_title.dropna(inplace=True)

# %%
recipe_ar_title.head()
# Out:
#                         recipe_title  \
# 0  Slow Cooker Chicken and Dumplings
# 1      Awesome Slow Cooker Pot Roast
# 2               Brown Sugar Meatloaf
# 3        Best Chocolate Chip Cookies
# 4  Homemade Mac and Cheese Casserole
#
#                                          ingredients
# 0  4 skinless, boneless chicken breast halves ADV...
# 1  2 (10.75 ounce) cans condensed cream of mushro...
# 2  1/2 cup packed brown sugar ADVERTISEMENT,1/2 c...
# 3  1 cup butter, softened ADVERTISEMENT,1 cup whi...
# 4  8 ounces whole wheat rotini pasta ADVERTISEMEN...

# %%
#remove word "ADVERTISEMENT" from ingredients
recipe_ar_title['ingredients'] = [s.replace('ADVERTISEMENT', '') for s in recipe_ar_title['ingredients']]

# %%
#remove numbers from ingredients
recipe_ar_title['ingredients'] = [re.sub(r'[0-9]+', '', s) for s in recipe_ar_title['ingredients']]

# %%
recipe_ar_title.head()
# Out:
#                         recipe_title  \
# 0  Slow Cooker Chicken and Dumplings
# 1      Awesome Slow Cooker Pot Roast
# 2               Brown Sugar Meatloaf
# 3        Best Chocolate Chip Cookies
# 4  Homemade Mac and Cheese Casserole
#
#                                          ingredients
# 0   skinless, boneless chicken breast halves , ta...
# 1   (. ounce) cans condensed cream of mushroom so...
# 2  / cup packed brown sugar ,/ cup ketchup , / po...
# 3   cup butter, softened , cup white sugar , cup ...
# 4   ounces whole wheat rotini pasta , cups fresh ...

# %% [markdown]
# #### Pre-process Text.....from NLP_Supervised_Learning

# %%
# lower case letters of recipes
recipe_ar_title['recipe_title'] = recipe_ar_title['recipe_title'].str.lower()
recipe_ar_title['ingredients'] = recipe_ar_title['ingredients'].str.lower()

# %%
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
#methods to remove stopwords and punctuation.

#remove stopwords
def remove_stopwords(input_text):
        stopwords_list = stopwords.words('english')
        whitelist = ["n't", "not", "no", "won’t"]
        words = input_text.split() 
        clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
        return " ".join(clean_words)
    
#remove punctuation
def remove_punctuation(input_text):
    tokenizer = RegexpTokenizer(r'\w+')
    result = tokenizer.tokenize(input_text)
    return " ".join(result)

# %%
# remove punctuation first and then stop words
recipe_ar_title['recipe_title'] = recipe_ar_title['recipe_title'].apply(remove_punctuation).apply(remove_stopwords)
recipe_ar_title['ingredients'] = recipe_ar_title['ingredients'].apply(remove_punctuation).apply(remove_stopwords)

# %%
recipe_ar_title.head()
# Out:
#                     recipe_title  \
# 0  slow cooker chicken dumplings
# 1  awesome slow cooker pot roast
# 2           brown sugar meatloaf
# 3    best chocolate chip cookies
# 4  homemade mac cheese casserole
#
#                                          ingredients
# 0  skinless boneless chicken breast halves tables...
# 1  ounce cans condensed cream mushroom soup ounce...
# 2  cup packed brown sugar cup ketchup pounds lean...
# 3  cup butter softened cup white sugar cup packed...
# 4  ounces whole wheat rotini pasta cups fresh bro...

# %% [markdown]
# #### EXPLORATORY ANALYSIS

# %%
# INGREDIANTS WORDCLOUD

# use wordcloud library.
from wordcloud import WordCloud

# Join the different processed titles together.
long_string = ','.join(list(recipe_ar_title['ingredients'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7FA20CBFA2D0>

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common terms in recipe ingredients')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('terms')
    plt.ylabel('counts')
    plt.show()
    
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(recipe_ar_title['ingredients'])
# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)
# Out:
# /Users/gunnuparinandi/anaconda3/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
